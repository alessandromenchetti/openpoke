# %%
import sqlite3
import pandas as pd
from pathlib import Path

# Point this to your repo root (or just hardcode the absolute path)
REPO_ROOT = Path(r"/Users/ale/Documents/Code Projects/openpoke")
DB_PATH = REPO_ROOT / "server" / "data" / "memory" / "memory_units.sqlite"
print(True if DB_PATH.exists() else False)

conn = sqlite3.connect(DB_PATH)

# Show tables
tables = pd.read_sql_query(
    "SELECT name FROM sqlite_master WHERE type='table' ORDER BY name;",
    conn
)
display(tables)
# Out:
# True
#               name
# 0     memory_units
# 1  sqlite_sequence

# %%
# Print the last 200 rows (most recent first)
df = pd.read_sql_query(
    """
    SELECT *
    FROM memory_units
    LIMIT 200;
    """,
    conn
)

display(df)
# Out:
#    id                                               text   unit_type  \
# 0  11                          User's name is Alessandro        fact
# 1  12              Alessandro's favourite colour is blue  preference
# 2  13  Catherine Bertucci is Alessandro's mother with...        fact
# 3  14  Isabella Menchetti is Alessandro's sister with...        fact
# 4  15  Alessandro confirmed dinner with Isabella on 2...  commitment
#
#                                        entities_json  confidence  \
# 0                                     ["Alessandro"]         1.0
# 1                                     ["Alessandro"]         1.0
# 2  ["Catherine Bertucci", "Alessandro", "c.bertuc...         0.9
# 3  ["Isabella Menchetti", "Alessandro", "isabella...         1.0
# 4               ["Alessandro", "Isabella Menchetti"]         0.9
#
#                          created_at source_refs_json  is_active  \
# 0  2026-01-27T22:53:16.680050+00:00               []          1
# 1  2026-01-27T22:53:16.682212+00:00               []          1
# 2  2026-01-27T22:53:16.685254+00:00               []          1
# 3  2026-01-27T22:53:16.688344+00:00               []          1
# 4  2026-01-27T22:53:16.690780+00:00               []          1
#
#                                           dedupe_key
# 0          fact|user's name is alessandro|alessandro
# 1  preference|alessandro's favourite colour is bl...
# 2  fact|catherine bertucci is alessandro's mother...
# 3  fact|isabella menchetti is alessandro's sister...
# 4  commitment|alessandro confirmed dinner with is...
